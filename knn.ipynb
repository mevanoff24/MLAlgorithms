# %% [markdown]
# # K-Nearest Neighbor

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

from instance.knn import KNN
from utils import *

# %%
X, y = get_simple_classification_data(random_state=104)
# train / test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=50, random_state=100)
# visualize dataset
plt.scatter(X_train[:, 0], X_train[:, 1], marker='o', c=y_train, s=25, edgecolor='k')
plt.show()

# %%
# init model
clf = KNN()
# fit model 
clf.fit(X_train, y_train)
train_accuracy = clf.score(X_train, y_train)
test_accuracy = clf.score(X_test, y_test)

print('train accuracy', train_accuracy)
print('test accuracy', test_accuracy)
# Out:
# train accuracy 0.88
# test accuracy 0.9

# %%
scores = {'train': {}, 'test': {}}
for k in range(1, 11):
    clf = KNN(n_neighbors=k)
    # fit model 
    clf.fit(X_train, y_train)
    train_accuracy = clf.score(X_train, y_train)
    test_accuracy = clf.score(X_test, y_test)
    scores['train'][k] = train_accuracy
    scores['test'][k] = test_accuracy
    
plt.plot(scores['train'].keys(), scores['train'].values(), 'o-', label='train')
plt.plot(scores['test'].keys(), scores['test'].values(), 'o-', label='test')
plt.title('Train / Test accuracy per n neighbors')
plt.legend();

# %% [markdown]
# **KNN**
# - Since KNN is a lazy learning method classification time is nonlinear, training is fast(simply memorize the data), however classification is slow.
# - The biggest strength is how simple and effective it is
# - Robust to noisy data, as long as an appropriate `n_neighbor` is used.
# - Effective with large amounts of data
# - Sensitive to irrelevant or redundant features as all features contribute to the similarity
